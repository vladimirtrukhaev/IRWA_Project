# %% [markdown]
# # PRACTICE
#
# #### Vladimir Trukhaev & Ingrid Sancho

# %%
#imports 
import nltk
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import re
import json
from collections import Counter

# %%
#updating/downloading stop words
nltk.download('stopwords')
#reading data
doc = "dataset_tweets_WHO.txt"
with open(doc, 'r') as file:
    data = json.load(file)
    
#initializing dictionary "my_dict" where value is the tweet text and key its id
keylist = []
for key in data:
    keylist.append(key)

my_dict = {}
docs_info = {}

for i in keylist:
    my_dict[i] = None
    docs_info[i] = None
    
for key in data:
    #initializing my_dict
    tweet = []
    for i in data[key]["full_text"]:
        tweet.append(i)
    tweet1 = "".join(tweet)
    my_dict[key] = tweet1
    
    #creting docs_info
    tweet = data[key]["full_text"]
    username = data[key]["user"]["name"]
    date = data[key]["created_at"]
    hashtags = data[key]["entities"]["hashtags"]
    likes = data[key]["favorite_count"]
    retweets = data[key]["retweet_count"]
    try:
        url = data[key]["entities"]["media"][0]["expanded_url"]
    except: #sometimes we weren't able to find the url in the data, then:
        url = "https://twitter.com/WHO/status/%s" % (data[key]["id_str"])
    
    info = {"tweet": tweet, "username": username, 
            "date": date, "hashtags": hashtags, 
            "likes": likes,"retweets": retweets, "url": url}
    docs_info[key] = info
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Ingrid\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Part 1: Text Processing

# %%
def lowering(d):
    """
    Transforming tweet text (values in dictionary) in lowercase
    
    Argument:
    d -- dictionary where tweets are stored as values
    
    Returns:
    d -- dictionary with tweets transformed to lowercase as values
    """
    for key in d:
        d[key] = d[key].lower()
    return d

def cleaning(d):
    """
    Removing anything that is not alphanumeric
    
    Argument:
    d -- dictionary where tweets are stored as values
    
    Returns:
    d -- dictionary with tweets without any non alphanumeric character
    """
    for key in d:
        d[key] = ["".join(re.sub(r'[^A-Za-z0-9 #]', ' ', i) for i in d[key])]
    return d

def tokenize(d):
    """
    Tokenizing the tweets, in other words, splitting text by "words"
    
    Argument:
    d -- dictionary where tweets are stored as values
    
    Returns:
    d -- dictionary with lists of words as values
    """
    for key in d:
        for sentence in d[key]:
            d[key] = sentence.split()
    return d

def stpwords(d):
    """
    Removing stopwords, which are very common words that do not contain meaning
    
    Argument:
    d -- dictionary where list of words of tweets are stored as values
    
    Returns:
    d -- dictionary with lists of words as values, now with no stopwords
    """
    languages = ["english", "spanish", "french"]
    for language in languages:
        stop_words = set(stopwords.words(language))
        for key in my_dict:
            my_dict[key] = [word for word in my_dict[key] if word not in stop_words]
    return d

def stemming(d):
    """
    Stemming tweets, which means to keep only the "root" of each word
    
    Argument:
    d -- dictionary where list of words of tweets are stored as values
    
    Returns:
    d -- dictionary with lists of words as values, now stemmed words
    """
    stemmer = PorterStemmer()
    for key in my_dict.keys():
        my_dict[key] = [stemmer.stem(word) for word in my_dict[key]]
    return d

# %%
#running every function for our dictionary of tweets "my_dict"
my_dict = lowering(my_dict)
my_dict = cleaning(my_dict)
my_dict = tokenize(my_dict)
my_dict = stpwords(my_dict)
my_dict = stemming(my_dict)

# %% [markdown]
# # Part 2:Indexing and Evaluation
#
# ## 11/11/21
#
# #### Vladimir Trukhaev & Ingrid Sancho

# %% [markdown]
# ### 2. Indexing

# %%
from collections import defaultdict
from array import array
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import math
import numpy as np
import collections
from numpy import linalg as la
import time

# %% [markdown]
# #### 2.1 Index Implementation

# %%
def create_index(my_dict):
    """
    Implement the inverted index
    
    Argument:
    lines -- collection of Wikipedia articles
    
    Returns:
    index - the inverted index (implemented through a Python dictionary) containing terms as keys and the corresponding
    list of documents where these keys appears in (and the positions) as values.
    """
    index = defaultdict(list)
    title_index = {}  # dictionary to map page titles to page ids
     ## ===============================================================        
        ## create the index for the current page and store it in current_page_index (current_page_index)
        ## current_page_index ==> { ‘term1’: [current_doc, [list of positions]], ...,‘term_n’: [current_doc, [list of positions]]}

        ## Example: if the curr_doc has id 1 and his text is 
        ##"web retrieval information retrieval":

        ## current_page_index ==> { ‘web’: [1, [0]], ‘retrieval’: [1, [1,4]], ‘information’: [1, [2]]}

        ## the term ‘web’ appears in document 1 in positions 0, 
        ## the term ‘retrieval’ appears in document 1 in positions 1 and 4
        ## ===============================================================
    for doc in my_dict:
        current_page_index = {}
        for position, term in enumerate(my_dict[doc]): # terms contains page_title + page_text. Loop over all terms
            try:
                  # if the term is already in the index for the current page (current_page_index)
                  # append the position to the corresponding list
          ## START CODE
                   current_page_index[term][1].append(position)  
            except:
                  # Add the new term as dict key and initialize the array of positions and add the position
                    current_page_index[term]=[doc, array('I',[position])] #'I' indicates unsigned int (int in Python)
              
          #merge the current page index with the main index
        for term_page, posting_page in current_page_index.items():
            index[term_page].append(posting_page)
          
          ## END CODE                    
                    
    return index

# %%
import time

start_time = time.time()
index = create_index(my_dict)
print("Total time to create the index: {} seconds".format(np.round(time.time() - start_time, 2 )))
# Out:
# Total time to create the index: 0.09 seconds

# %%
print("Index results for the term 'researcher': {}\n".format(index['researcher']))
print("First 10 Index results for the term 'research': \n{}".format(index['research']))
# Out:
# Index results for the term 'researcher': []
#
# First 10 Index results for the term 'research':
# [['22', array('I', [17])], ['153', array('I', [21])], ['171', array('I', [17])], ['203', array('I', [5])], ['210', array('I', [10])], ['211', array('I', [7])], ['221', array('I', [6])], ['422', array('I', [12])], ['428', array('I', [4])], ['459', array('I', [23])], ['814', array('I', [0])], ['960', array('I', [4])], ['1246', array('I', [14])], ['1341', array('I', [9])], ['1383', array('I', [3, 13])], ['1384', array('I', [14])], ['1389', array('I', [6])], ['1391', array('I', [10])], ['1392', array('I', [22])], ['1393', array('I', [5])], ['1394', array('I', [15])], ['1419', array('I', [26])], ['1611', array('I', [13])], ['1630', array('I', [2])], ['1784', array('I', [7])], ['1941', array('I', [4])], ['1972', array('I', [11])], ['2063', array('I', [15, 23])], ['2101', array('I', [10])], ['2103', array('I', [10])], ['2324', array('I', [12])]]

# %% [markdown]
# #### 2.2 Querying the Index

# %%
def build_terms(line):
    """
    Preprocess the article text (title + body) removing stop words, stemming,
    transforming in lowercase and return the tokens of the text.
    
    Argument:
    line -- string (text) to be preprocessed
    
    Returns:
    line - a list of tokens corresponding to the input text after the preprocessing
    """

    stemmer = PorterStemmer()
    stop_words = set(stopwords.words("english"))
    ## START CODE
    line=  line.lower() ## Transform in lowercase
    line=  line.split() ## Tokenize the text to get a list of terms
    line=[word for word in line if not word in stop_words]  ##eliminate the stopwords (HINT: use List Comprehension)
    line=[stemmer.stem(word) for word in line] ## perform stemming (HINT: use List Comprehension)
    ## END CODE
    return line

# %%
def search(query, index):
    """
    The output is the list of documents that contain any of the query terms. 
    So, we will get the list of documents for each query term, and take the union of them.
    """
    query = build_terms(query)
    docs = set()
    for term in query:
    ## START DODE
        try:
            # store in term_docs the ids of the docs that contain "term"                        
            term_docs=[posting[0] for posting in index[term]]
            # docs = docs Union term_docs
            docs = docs.union(term_docs)
        except:
            #term is not in index
            pass
    docs = list(docs)
    return docs

# %%
#defining docs_info from original data
doc = "dataset_tweets_WHO.txt"
with open(doc, 'r') as file:
    data = json.load(file)
    
#initializing dictionary "my_dict" where value is the tweet text and key its id
keylist = []
for key in data:
    keylist.append(key)

docs_info = {}
    
for i in keylist:
    docs_info[i] = None
    
for key in data:
    tweet = data[key]["full_text"]
    username = data[key]["user"]["name"]
    date = data[key]["created_at"]
    hashtags = data[key]["entities"]["hashtags"]
    likes = data[key]["favorite_count"]
    retweets = data[key]["retweet_count"]
    try:
        url = data[key]["entities"]["media"][0]["expanded_url"]
    except: #sometimes we weren't able to find the url in the data, then:
        url = "https://twitter.com/WHO/status/%s" % (data[key]["id_str"])
    
    info = {"tweet": tweet, "username": username, 
            "date": date, "hashtags": hashtags, 
            "likes": likes,"retweets": retweets, "url": url}
    docs_info[key] = info

# %%
print("Insert your query (i.e.: Computer Science):\n")
query = input()
docs = search(query, index)
top = 10

print("\n======================\nSample of {} results out of {} for the searched query:\n".format(top, len(docs)))
for d_id in docs[:top]:
    info_list = ["tweet","username","date","hashtags","likes","retweets","url"]
    print("DOC", d_id, "has been retrieved")
    for i in info:
        print(i,":",docs_info[d_id][i])
    print("\n")
# Out:
# Insert your query (i.e.: Computer Science):
#
# Covid help
#
# ======================
# Sample of 10 results out of 181 for the searched query:
#
# DOC 1264 has been retrieved
# tweet : @DrTedros "Our colleagues at @pahowho have helped send emergency medical teams &amp; supplies. They have also been on the ground supporting the authorities with an assessment of the damage to health facilities. Four have been destroyed &amp; a further 20 damaged"-@DrTedros https://t.co/BTTucE6d3d
# username : World Health Organization (WHO)
# date : Wed Aug 18 13:31:48 +0000 2021
# hashtags : []
# likes : 57
# retweets : 20
# url : https://twitter.com/WHO/status/1427986589842608130
#
#
# DOC 1453 has been retrieved
# tweet : While #COVID19 cases are slowing down in some part of the world, WHO steps up the fight to help countries still facing surges in infections and new challenges.
#
# Read more 👉https://t.co/LXb0xnuP7i #WHOImpact https://t.co/aluig4piUX
# username : World Health Organization (WHO)
# date : Sat Aug 07 12:56:52 +0000 2021
# hashtags : [{'text': 'COVID19', 'indices': [6, 14]}, {'text': 'WHOImpact', 'indices': [196, 206]}]
# likes : 168
# retweets : 38
# url : https://twitter.com/WHO/status/1423991531942203405/photo/1
#
#
# DOC 805 has been retrieved
# tweet : RT @DrTedros: If you know someone who may be considering #suicide, here is some advice on how to reach out and offer help ⬇️
#
# #WorldSuicide…
# username : World Health Organization (WHO)
# date : Fri Sep 10 19:51:09 +0000 2021
# hashtags : [{'text': 'suicide', 'indices': [57, 65]}]
# likes : 0
# retweets : 103
# url : https://twitter.com/WHO/status/1436416976642056193
#
#
# DOC 1756 has been retrieved
# tweet : #Sudan 🇸🇩 is helping people speak up about their health in community dialogues.The initiative helps find solutions and ensure people can hold their local health authorities accountable.
#
# 👉https://t.co/PYSjgi3F5i #WHOImpact #UHCPartnership https://t.co/VbfbK0kwnt
# username : World Health Organization (WHO)
# date : Tue Jul 27 08:13:40 +0000 2021
# hashtags : [{'text': 'Sudan', 'indices': [0, 6]}, {'text': 'WHOImpact', 'indices': [212, 222]}, {'text': 'UHCPartnership', 'indices': [223, 238]}]
# likes : 139
# retweets : 23
# url : https://twitter.com/WHO/status/1419933995953840130/photo/1
#
#
# DOC 253 has been retrieved
# tweet : Ageism affects people of all ages.
# It has detrimental costs on our health, wellbeing, social systems and our economy.
# It’s time for change.
#
# Download our guide to start the conversation and help create #AWorld4AllAges 👇
# username : World Health Organization (WHO)
# date : Sun Oct 03 12:41:38 +0000 2021
# hashtags : [{'text': 'AWorld4AllAges', 'indices': [202, 217]}]
# likes : 312
# retweets : 115
# url : https://twitter.com/WHO/status/1444643807711137792
#
#
# DOC 293 has been retrieved
# tweet : Investment in universal health coverage has far-reaching impacts beyond health. It can also help us create stronger, more sustainable and more equitable economies and societies that leave no one behind.
#
# #HealthForAll #UNGA https://t.co/Z6OPrOFOoR
# username : World Health Organization (WHO)
# date : Thu Sep 30 15:00:00 +0000 2021
# hashtags : [{'text': 'HealthForAll', 'indices': [205, 218]}, {'text': 'UNGA', 'indices': [219, 224]}]
# likes : 132
# retweets : 39
# url : https://twitter.com/WHO/status/1443591466048126986/photo/1
#
#
# DOC 2023 has been retrieved
# tweet : To help people make an informed decision about if &amp; where to swim 🤽‍many countries around the world:
# 🌊 regularly monitor water quality
# 🚧 implement measures to reduce pollution
# ℹ️ provide information to the public
#
# 👉https://t.co/RLE664bqSc https://t.co/kPuyYWDwvz
# username : World Health Organization (WHO)
# date : Tue Jul 13 15:24:37 +0000 2021
# hashtags : []
# likes : 152
# retweets : 28
# url : https://twitter.com/WHO/status/1414969018918768643/photo/1
#
#
# DOC 601 has been retrieved
# tweet : "They can also help to inform and strengthen policies in sectors including energy, waste-management, agriculture and transport"-@DrTedros #AirPollution
# username : World Health Organization (WHO)
# date : Wed Sep 22 13:30:09 +0000 2021
# hashtags : [{'text': 'AirPollution', 'indices': [138, 151]}]
# likes : 111
# retweets : 26
# url : https://twitter.com/WHO/status/1440669751076786185
#
#
# DOC 100 has been retrieved
# tweet : If someone you know has #depression, here is how you can help:
# 💙 Talk to them and offer your support
# 💙 Encourage them to seek professional help
# 💙 Help them with everyday activities
#
# #WorldMentalHealthDay #LetsTalk https://t.co/Jb6VAb19JH
# username : World Health Organization (WHO)
# date : Sun Oct 10 06:58:15 +0000 2021
# hashtags : [{'text': 'depression', 'indices': [24, 35]}, {'text': 'WorldMentalHealthDay', 'indices': [182, 203]}, {'text': 'LetsTalk', 'indices': [204, 213]}]
# likes : 333
# retweets : 152
# url : https://twitter.com/WHO/status/1447094107155931137/photo/1
#
#
# DOC 1439 has been retrieved
# tweet : 20% of 🌐 carbon emissions are from transportation.
#
# Each of us can help reduce the emissions by walking 🚶‍ and cycling 🚴‍more for your health and the health of the planet.
#
# #ClimateChange
#
# 👉 https://t.co/moAcOoZJsD https://t.co/RxMCKnFIfa
# username : World Health Organization (WHO)
# date : Mon Aug 09 16:03:43 +0000 2021
# hashtags : [{'text': 'ClimateChange', 'indices': [175, 189]}]
# likes : 189
# retweets : 68
# url : https://twitter.com/WHO/status/1424763331391467520/photo/1

# %% [markdown]
# #### 2.3. Add Ranking with TF-IDF

# %%
def create_index_tfidf(my_dict, num_documents):
    """
    Implement the inverted index and compute tf, df and idf
    
    Argument:
    lines -- collection of Wikipedia articles
    num_documents -- total number of documents
    
    Returns:
    index - the inverted index (implemented through a Pyhon dictionary) containing terms as keys and the corresponding
    list of document these keys appears in (and the positions) as values.
    tf - normalized term frequency for each term in each document
    df - number of documents each term appear in
    idf - inverse document frequency of each term
    """

    index = defaultdict(list)
    tf = defaultdict(list)  #term frequencies of terms in documents (documents in the same order as in the main index)
    df = defaultdict(int)  #document frequencies of terms in the corpus
    idf = defaultdict(float)

     ## ===============================================================        
        ## create the index for the current page and store it in current_page_index (current_page_index)
        ## current_page_index ==> { ‘term1’: [current_doc, [list of positions]], ...,‘term_n’: [current_doc, [list of positions]]}

        ## Example: if the curr_doc has id 1 and his text is 
        ##"web retrieval information retrieval":

        ## current_page_index ==> { ‘web’: [1, [0]], ‘retrieval’: [1, [1,4]], ‘information’: [1, [2]]}

        ## the term ‘web’ appears in document 1 in positions 0, 
        ## the term ‘retrieval’ appears in document 1 in positions 1 and 4
        ## ===============================================================
    for doc in my_dict:
        current_page_index = {}
        for position, term in enumerate(my_dict[doc]): # terms contains page_title + page_text. Loop over all terms
            try:
                  # if the term is already in the index for the current page (current_page_index)
                  # append the position to the corresponding list
          ## START CODE
                   current_page_index[term][1].append(position)  
            except:
                  # Add the new term as dict key and initialize the array of positions and add the position
                    current_page_index[term]=[doc, array('I',[position])] #'I' indicates unsigned int (int in Python)
              
        #normalize term frequencies
        # Compute the denominator to normalize term frequencies (formula 2 above)
        # norm is the same for all terms of a document.
        norm = 0
        for term, posting in current_page_index.items():
            # posting will contain the list of positions for current term in current document. 
            # posting ==> [current_doc, [list of positions]] 
            # you can use it to infer the frequency of current term.
            norm += len(posting) ** 2
        norm = math.sqrt(norm)

        #calculate the tf(dividing the term frequency by the above computed norm) and df weights
        for term, posting in current_page_index.items():
            # append the tf for current term (tf = term frequency in current doc/norm)
            tf[term].append(np.round(len(posting)/norm,4)) ## SEE formula (1) above
            #increment the document frequency of current term (number of documents containing the current term)
            df[term] = tf[term] # increment DF for current term

        #merge the current page index with the main index
        for term_page, posting_page in current_page_index.items():
            index[term_page].append(posting_page)

        # Compute IDF following the formula (3) above. HINT: use np.log
        for term in df:
            idf[term] = np.round(np.log(float(num_documents/len(df[term]))), 4)

    return index, tf, df, idf

# %%
start_time = time.time()
num_documents = len(my_dict)
index, tf, df, idf = create_index_tfidf(my_dict, num_documents)
print("Total time to create the index: {} seconds" .format(np.round(time.time() - start_time, 2)))
# Out:
# Total time to create the index: 84.14 seconds

# %%
index
# Out:
# defaultdict(list,
#             {'intern': [['0', array('I', [0])],
#               ['2', array('I', [0])],
#               ['35', array('I', [1])],
#               ['262', array('I', [0])],
#               ['273', array('I', [0])],
#               ['277', array('I', [0])],
#               ['278', array('I', [1])],
#               ['280', array('I', [1])],
#               ['299', array('I', [0])],
#               ['338', array('I', [0])],
#               ['359', array('I', [18])],
#               ['363', array('I', [10])],
#               ['389', array('I', [16])],
#               ['450', array('I', [7, 14])],
#               ['458', array('I', [6])],
#               ['498', array('I', [7])],
#               ['553', array('I', [10])],
#               ['584', array('I', [0])],
#               ['677', array('I', [2])],
#               ['761', array('I', [8])],
#               ['776', array('I', [7])],
#               ['779', array('I', [3])],
#               ['856', array('I', [8])],
#               ['881', array('I', [0])],
#               ['886', array('I', [0])],
#               ['898', array('I', [0])],
#               ['1038', array('I', [0])],
#               ['1040', array('I', [0])],
#               ['1041', array('I', [0])],
#               ['1077', array('I', [3, 6])],
#               ['1117', array('I', [5])],
#               ['1138', array('I', [4])],
#               ['1141', array('I', [4, 11])],
#               ['1260', array('I', [11])],
#               ['1285', array('I', [9])],
#               ['1355', array('I', [3])],
#               ['1368', array('I', [10])],
#               ['1372', array('I', [7])],
#               ['1373', array('I', [7])],
#               ['1374', array('I', [7])],
#               ['1375', array('I', [7])],
#               ['1376', array('I', [7])],
#               ['1379', array('I', [7])],
#               ['1381', array('I', [0])],
#               ['1644', array('I', [5])],
#               ['1673', array('I', [17])],
#               ['1677', array('I', [6])],
#               ['1695', array('I', [9])],
#               ['1791', array('I', [2])],
#               ['1792', array('I', [7])],
#               ['1801', array('I', [20])],
#               ['1872', array('I', [0])],
#               ['1877', array('I', [0])],
#               ['1908', array('I', [24])],
#               ['1938', array('I', [2])],
#               ['1941', array('I', [8])],
#               ['1946', array('I', [5])],
#               ['1977', array('I', [8])],
#               ['1979', array('I', [8])],
#               ['2013', array('I', [19])],
#               ['2014', array('I', [5])],
#               ['2016', array('I', [0])],
#               ['2037', array('I', [20])],
#               ['2093', array('I', [19])],
#               ['2103', array('I', [9])],
#               ['2217', array('I', [15])],
#               ['2236', array('I', [2])],
#               ['2301', array('I', [2])],
#               ['2365', array('I', [17])],
#               ['2369', array('I', [8])],
#               ['2371', array('I', [13])],
#               ['2373', array('I', [15])]],
#              'day': [['0', array('I', [1])],
#               ['2', array('I', [1])],
#               ['34', array('I', [17])],
#               ['112', array('I', [4])],
#               ['116', array('I', [5])],
#               ['134', array('I', [5])],
#               ['203', array('I', [7])],
#               ['221', array('I', [8, 16, 18])],
#               ['235', array('I', [19])],
#               ['237', array('I', [4])],
#               ['262', array('I', [1])],
#               ['273', array('I', [1])],
#               ['275', array('I', [7])],
#               ['277', array('I', [1])],
#               ['278', array('I', [2])],
#               ['280', array('I', [2])],
#               ['291', array('I', [14])],
#               ['315', array('I', [9])],
#               ['348', array('I', [2])],
#               ['352', array('I', [12])],
#               ['486', array('I', [7])],
#               ['515', array('I', [18])],
#               ['523', array('I', [0])],
#               ['584', array('I', [1])],
#               ['630', array('I', [7])],
#               ['655', array('I', [13])],
#               ['704', array('I', [5])],
#               ['707', array('I', [2])],
#               ['734', array('I', [13])],
#               ['767', array('I', [14])],
#               ['776', array('I', [12])],
#               ['886', array('I', [1])],
#               ['898', array('I', [1])],
#               ['918', array('I', [1])],
#               ['924', array('I', [3])],
#               ['928', array('I', [13])],
#               ['980', array('I', [22])],
#               ['1065', array('I', [7])],
#               ['1187', array('I', [4])],
#               ['1196', array('I', [4])],
#               ['1202', array('I', [3])],
#               ['1405', array('I', [17])],
#               ['1490', array('I', [9])],
#               ['1531', array('I', [4])],
#               ['1598', array('I', [23])],
#               ['1733', array('I', [5])],
#               ['1810', array('I', [21])],
#               ['1814', array('I', [2])],
#               ['1815', array('I', [4])],
#               ['1818', array('I', [3])],
#               ['1819', array('I', [11])],
#               ['1890', array('I', [7])],
#               ['2037', array('I', [12])],
#               ['2170', array('I', [5])],
#               ['2183', array('I', [4])],
#               ['2209', array('I', [1, 2])],
#               ['2213', array('I', [3])],
#               ['2248', array('I', [13, 22])],
#               ['2274', array('I', [10])],
#               ['2292', array('I', [23])],
#               ['2354', array('I', [5, 13])],
#               ['2357', array('I', [2])],
#               ['2361', array('I', [17])],
#               ['2363', array('I', [14])],
#               ['2393', array('I', [2])],
#               ['2395', array('I', [1])]],
#              'disast': [['0', array('I', [2])],
#               ['1', array('I', [4])],
#               ['2', array('I', [2])],
#               ['429', array('I', [14])],
#               ['1200', array('I', [5])],
#               ['1213', array('I', [2])],
#               ['1256', array('I', [10])],
#               ['2181', array('I', [13, 19])],
#               ['2293', array('I', [6])],
#               ['2366', array('I', [14])]],
#              'risk': [['0', array('I', [3])],
#               ['2', array('I', [3])],
#               ['9', array('I', [13])],
#               ['28', array('I', [23])],
#               ['37', array('I', [4, 22])],
#               ['58', array('I', [10])],
#               ['92', array('I', [2])],
#               ['95', array('I', [2])],
#               ['96', array('I', [1])],
#               ['97', array('I', [18])],
#               ['166', array('I', [19])],
#               ['168', array('I', [16])],
#               ['185', array('I', [24])],
#               ['186', array('I', [13])],
#               ['189', array('I', [18])],
#               ['232', array('I', [9])],
#               ['236', array('I', [20])],
#               ['247', array('I', [13])],
#               ['258', array('I', [2])],
#               ['270', array('I', [6])],
#               ['294', array('I', [21])],
#               ['304', array('I', [6])],
#               ['319', array('I', [4])],
#               ['323', array('I', [11])],
#               ['508', array('I', [9])],
#               ['541', array('I', [16, 19])],
#               ['549', array('I', [7])],
#               ['564', array('I', [9, 14])],
#               ['565', array('I', [17])],
#               ['571', array('I', [13])],
#               ['598', array('I', [14])],
#               ['607', array('I', [4])],
#               ['665', array('I', [14])],
#               ['672', array('I', [20])],
#               ['696', array('I', [4])],
#               ['705', array('I', [6])],
#               ['731', array('I', [14])],
#               ['753', array('I', [14])],
#               ['758', array('I', [8])],
#               ['793', array('I', [6])],
#               ['794', array('I', [5])],
#               ['801', array('I', [23])],
#               ['802', array('I', [26])],
#               ['814', array('I', [19])],
#               ['816', array('I', [0])],
#               ['839', array('I', [15])],
#               ['842', array('I', [16])],
#               ['844', array('I', [5])],
#               ['846', array('I', [14])],
#               ['860', array('I', [13])],
#               ['912', array('I', [3])],
#               ['928', array('I', [2])],
#               ['934', array('I', [4])],
#               ['969', array('I', [5])],
#               ['1001', array('I', [8])],
#               ['1002', array('I', [15])],
#               ['1013', array('I', [15])],
#               ['1037', array('I', [2])],
#               ['1040', array('I', [15])],
#               ['1051', array('I', [17])],
#               ['1074', array('I', [9])],
#               ['1094', array('I', [10])],
#               ['1100', array('I', [9])],
#               ['1133', array('I', [15])],
#               ['1176', array('I', [8])],
#               ['1178', array('I', [11])],
#               ['1244', array('I', [16])],
#               ['1254', array('I', [21])],
#               ['1276', array('I', [9])],
#               ['1288', array('I', [7])],
#               ['1291', array('I', [5, 9, 11])],
#               ['1292', array('I', [9, 14, 16])],
#               ['1293', array('I', [8, 10])],
#               ['1294', array('I', [10, 12])],
#               ['1295', array('I', [8, 10])],
#               ['1309', array('I', [1])],
#               ['1342', array('I', [14])],
#               ['1343', array('I', [15])],
#               ['1348', array('I', [20])],
#               ['1366', array('I', [22])],
#               ['1368', array('I', [6])],
#               ['1369', array('I', [18])],
#               ['1386', array('I', [10])],
#               ['1403', array('I', [13])],
#               ['1419', array('I', [18])],
#               ['1425', array('I', [13])],
#               ['1435', array('I', [15])],
#               ['1442', array('I', [2])],
#               ['1447', array('I', [3])],
#               ['1474', array('I', [6])],
#               ['1475', array('I', [13])],
#               ['1479', array('I', [12])],
#               ['1486', array('I', [11])],
#               ['1491', array('I', [6])],
#               ['1523', array('I', [11])],
#               ['1569', array('I', [7])],
#               ['1594', array('I', [4])],
#               ['1622', array('I', [11])],
#               ['1624', array('I', [8])],
#               ['1635', array('I', [10])],
#               ['1670', array('I', [2])],
#               ['1715', array('I', [5, 7])],
#               ['1718', array('I', [22])],
#               ['1746', array('I', [6])],
#               ['1811', array('I', [23])],
#               ['1813', array('I', [1])],
#               ['1824', array('I', [10, 12])],
#               ['1825', array('I', [8, 10])],
#               ['1846', array('I', [16])],
#               ['1875', array('I', [11])],
#               ['1916', array('I', [4, 6, 8])],
#               ['1955', array('I', [2])],
#               ['1962', array('I', [8])],
#               ['1963', array('I', [6])],
#               ['2004', array('I', [18])],
#               ['2008', array('I', [7])],
#               ['2021', array('I', [4])],
#               ['2108', array('I', [23])],
#               ['2137', array('I', [9])],
#               ['2140', array('I', [13])],
#               ['2151', array('I', [4])],
#               ['2153', array('I', [6])],
#               ['2196', array('I', [13])],
#               ['2207', array('I', [4])],
#               ['2243', array('I', [15])],
#               ['2272', array('I', [18])],
#               ['2289', array('I', [17])],
#               ['2304', array('I', [1, 13, 21])],
#               ['2317', array('I', [2])],
#               ['2318', array('I', [0])],
#               ['2323', array('I', [9, 14])],
#               ['2342', array('I', [2])],
#               ['2343', array('I', [8, 16])],
#               ['2380', array('I', [23])],
#               ['2388', array('I', [17])]],
#              'reduct': [['0', array('I', [4])],
#               ['2', array('I', [4])],
#               ['514', array('I', [7])],
#               ['783', array('I', [4])],
#               ['1237', array('I', [10])],
#               ['1419', array('I', [19])],
#               ['2296', array('I', [11])]],
#              '#openwho': [['0', array('I', [5])],
#               ['299', array('I', [16])],
#               ['339', array('I', [13])],
#               ['584', array('I', [5])],
#               ['881', array('I', [6])],
#               ['905', array('I', [23])],
#               ['913', array('I', [10])],
#               ['933', array('I', [16])],
#               ['1049', array('I', [16])],
#               ['1058', array('I', [15])],
#               ['1193', array('I', [21])],
#               ['1274', array('I', [3])],
#               ['1275', array('I', [15])],
#               ['1448', array('I', [14])],
#               ['1565', array('I', [10])],
#               ['1665', array('I', [5])],
#               ['1786', array('I', [13])],
#               ['1943', array('I', [21])],
#               ['2022', array('I', [18])]],
#              'launch': [['0', array('I', [6])],
#               ['168', array('I', [1])],
#               ['192', array('I', [3])],
#               ['237', array('I', [16])],
#               ['240', array('I', [8])],
#               ['247', array('I', [6])],
#               ['341', array('I', [5])],
#               ['417', array('I', [8])],
#               ['439', array('I', [6])],
#               ['494', array('I', [2])],
#               ['529', array('I', [1])],
#               ['605', array('I', [2])],
#               ['609', array('I', [1])],
#               ['866', array('I', [4])],
#               ['891', array('I', [4])],
#               ['1070', array('I', [1])],
#               ['1247', array('I', [21])],
#               ['1275', array('I', [8])],
#               ['1288', array('I', [3])],
#               ['1423', array('I', [5])],
#               ['1550', array('I', [2])],
#               ['1618', array('I', [9])],
#               ['1750', array('I', [1])],
#               ['1877', array('I', [5])],
#               ['1942', array('I', [2])],
#               ['1943', array('I', [17])],
#               ['2024', array('I', [4])],
#               ['2187', array('I', [2])],
#               ['2216', array('I', [2])],
#               ['2300', array('I', [13])]],
#              'multi': [['0', array('I', [7])], ['2178', array('I', [8])]],
#              'tier': [['0', array('I', [8])]],
#              'core': [['0', array('I', [9])],
#               ['1080', array('I', [8])],
#               ['1695', array('I', [6])]],
#              'curriculum': [['0', array('I', [10])],
#               ['1275', array('I', [13])],
#               ['1943', array('I', [19])]],
#              'help': [['0', array('I', [11])],
#               ['39', array('I', [7])],
#               ['57', array('I', [7])],
#               ['61', array('I', [6])],
#               ['65', array('I', [14])],
#               ['66', array('I', [14])],
#               ['69', array('I', [10])],
#               ['70', array('I', [14])],
#               ['75', array('I', [11])],
#               ['78', array('I', [9])],
#               ['80', array('I', [7])],
#               ['95', array('I', [9])],
#               ['99', array('I', [3])],
#               ['100', array('I', [3, 10, 11])],
#               ['103', array('I', [2])],
#               ['104', array('I', [7])],
#               ['110', array('I', [9])],
#               ['114', array('I', [10])],
#               ['115', array('I', [3])],
#               ['123', array('I', [5])],
#               ['126', array('I', [1, 13])],
#               ['141', array('I', [7])],
#               ['162', array('I', [5])],
#               ['168', array('I', [4])],
#               ['171', array('I', [3])],
#               ['175', array('I', [3])],
#               ['237', array('I', [19])],
#               ['240', array('I', [1])],
#               ['253', array('I', [17])],
#               ['255', array('I', [12])],
#               ['262', array('I', [6])],
#               ['267', array('I', [1])],
#               ['271', array('I', [0])],
#               ['278', array('I', [14])],
#               ['293', array('I', [10])],
#               ['399', array('I', [16])],
#               ['416', array('I', [13])],
#               ['442', array('I', [21])],
#               ['447', array('I', [26])],
#               ['458', array('I', [15])],
#               ['478', array('I', [12, 16])],
#               ['479', array('I', [6])],
#               ['488', array('I', [3])],
#               ['489', array('I', [15])],
#               ['519', array('I', [7, 10])],
#               ['541', array('I', [12])],
#               ['588', array('I', [10])],
#               ['597', array('I', [12])],
#               ['601', array('I', [1])],
#               ['671', array('I', [19])],
#               ['675', array('I', [13])],
#               ['691', array('I', [10])],
#               ['768', array('I', [2])],
#               ['777', array('I', [2])],
#               ['801', array('I', [4])],
#               ['803', array('I', [16])],
#               ['804', array('I', [6])],
#               ['805', array('I', [10])],
#               ['809', array('I', [10])],
#               ['810', array('I', [11])],
#               ['812', array('I', [18])],
#               ['813', array('I', [6])],
#               ['817', array('I', [6])],
#               ['819', array('I', [7])],
#               ['877', array('I', [3])],
#               ['893', array('I', [24])],
#               ['1007', array('I', [6])],
#               ['1013', array('I', [27])],
#               ['1035', array('I', [7])],
#               ['1099', array('I', [10])],
#               ['1104', array('I', [5])],
#               ['1107', array('I', [23])],
#               ['1164', array('I', [17])],
#               ['1178', array('I', [1])],
#               ['1204', array('I', [8])],
#               ['1244', array('I', [7])],
#               ['1251', array('I', [13])],
#               ['1259', array('I', [15])],
#               ['1264', array('I', [3])],
#               ['1268', array('I', [13])],
#               ['1279', array('I', [16])],
#               ['1302', array('I', [8])],
#               ['1310', array('I', [3])],
#               ['1313', array('I', [2])],
#               ['1322', array('I', [12])],
#               ['1325', array('I', [2])],
#               ['1327', array('I', [3])],
#               ['1332', array('I', [8])],
#               ['1338', array('I', [7])],
#               ['1369', array('I', [13])],
#               ['1377', array('I', [5])],
#               ['1379', array('I', [12])],
#               ['1417', array('I', [0])],
#               ['1423', array('I', [6])],
#               ['1439', array('I', [5])],
#               ['1453', array('I', [7])],
#               ['1469', array('I', [2])],
#               ['1480', array('I', [4])],
#               ['1486', array('I', [7])],
#               ['1495', array('I', [16])],
#               ['1496', array('I', [4])],
#               ['1497', array('I', [4])],
#               ['1522', array('I', [7])],
#               ['1547', array('I', [18])],
#               ['1555', array('I', [13])],
#               ['1560', array('I', [5])],
#               ['1566', array('I', [6])],
#               ['1570', array('I', [13])],
#               ['1578', array('I', [5])],
#               ['1598', array('I', [19])],
#               ['1599', array('I', [10])],
#               ['1634', array('I', [6])],
#               ['1652', array('I', [16])],
#               ['1664', array('I', [11])],
#               ['1694', array('I', [15])],
#               ['1706', array('I', [11])],
#               ['1743', array('I', [5])],
#               ['1756', array('I', [1, 8])],
#               ['1769', array('I', [2])],
#               ['1780', array('I', [2])],
#               ['1819', array('I', [0])],
#               ['1829', array('I', [2])],
#               ['1850', array('I', [22])],
#               ['1868', array('I', [3])],
#               ['1869', array('I', [12])],
#               ['1872', array('I', [11])],
#               ['1943', array('I', [8])],
#               ['1972', array('I', [16])],
#               ['2018', array('I', [13])],
#               ['2023', array('I', [0])],
#               ['2032', array('I', [1])],
#               ['2065', array('I', [6])],
#               ['2067', array('I', [12, 16])],
#               ['2095', array('I', [15])],
#               ['2104', array('I', [5])],
#               ['2125', array('I', [4])],
#               ['2139', array('I', [15])],
#               ['2148', array('I', [5])],
#               ['2151', array('I', [15])],
#               ['2158', array('I', [2])],
#               ['2164', array('I', [1])],
#               ['2166', array('I', [16])],
#               ['2218', array('I', [1])],
#               ['2251', array('I', [5])],
#               ['2281', array('I', [5])],
#               ['2327', array('I', [14])],
#               ['2331', array('I', [1])],
#               ['2357', array('I', [14])],
#               ['2385', array('I', [2])],
#               ['2393', array('I', [19])],
#               ['2395', array('I', [9])]],
#              'equip': [['0', array('I', [12])],
#               ['500', array('I', [18])],
#               ['503', array('I', [18])],
#               ['569', array('I', [6])],
#               ['611', array('I', [30])],
#               ['633', array('I', [8])],
#               ['863', array('I', [11])],
#               ['1009', array('I', [8])],
#               ['1030', array('I', [15])],
#               ['1034', array('I', [21])],
#               ['1246', array('I', [11])],
#               ['1300', array('I', [10])],
#               ['1451', array('I', [6])],
#               ['1483', array('I', [10])],
#               ['1637', array('I', [23])],
#               ['2053', array('I', [14])],
#               ['2147', array('I', [6])],
#               ['2166', array('I', [4])]],
#              'compet': [['0', array('I', [13])],
#               ['413', array('I', [17])],
#               ['416', array('I', [4])],
#               ['426', array('I', [15])],
#               ['434', array('I', [15])],
#               ['441', array('I', [15])],
#               ['454', array('I', [26])],
#               ['1128', array('I', [11])]],
#              'need': [['0', array('I', [14])],
#               ['11', array('I', [9])],
#               ['23', array('I', [18])],
#               ['25', array('I', [3])],
#               ['67', array('I', [13])],
#               ['77', array('I', [2])],
#               ['78', array('I', [2])],
#               ['112', array('I', [10])],
#               ['113', array('I', [2])],
#               ['115', array('I', [13])],
#               ['116', array('I', [8])],
#               ['134', array('I', [12, 16])],
#               ['136', array('I', [24])],
#               ['140', array('I', [14])],
#               ['142', array('I', [1])],
#               ['146', array('I', [2])],
#               ['155', array('I', [8])],
#               ['156', array('I', [6])],
#               ['163', array('I', [4])],
#               ['164', array('I', [15])],
#               ['177', array('I', [11])],
#               ['189', array('I', [11])],
#               ['213', array('I', [12])],
#               ['216', array('I', [3])],
#               ['233', array('I', [17])],
#               ['234', array('I', [11])],
#               ['256', array('I', [2])],
#               ['260', array('I', [4])],
#               ['262', array('I', [7])],
#               ['265', array('I', [6])],
#               ['269', array('I', [0])],
#               ['275', array('I', [13])],
#               ['298', array('I', [14])],
#               ['303', array('I', [11])],
#               ['309', array('I', [4])],
#               ['346', array('I', [3])],
#               ['360', array('I', [8])],
#               ['361', array('I', [3])],
#               ['372', array('I', [7])],
#               ['374', array('I', [10])],
#               ['384', array('I', [18])],
#               ['404', array('I', [9])],
#               ['441', array('I', [9])],
#               ['442', array('I', [3])],
#               ['444', array('I', [6])],
#               ['445', array('I', [7])],
#               ['446', array('I', [16, 20])],
#               ['454', array('I', [17])],
#               ['460', array('I', [18])],
#               ['496', array('I', [17])],
#               ['500', array('I', [5, 20])],
#               ['502', array('I', [5])],
#               ['503', array('I', [7])],
#               ['504', array('I', [3])],
#               ['506', array('I', [6])],
#               ['511', array('I', [17])],
#               ['517', array('I', [11])],
#               ['518', array('I', [1])],
#               ['521', array('I', [1])],
#               ['522', array('I', [7, 16])],
#               ['527', array('I', [10])],
#               ['551', array('I', [15])],
#               ['552', array('I', [13])],
#               ['553', array('I', [8])],
#               ['554', array('I', [9])],
#               ['577', array('I', [1, 6])],
#               ['580', array('I', [0])],
#               ['586', array('I', [7])],
#               ['612', array('I', [8])],
#               ['614', array('I', [22])],
#               ['617', array('I', [13])],
#               ['624', array('I', [4])],
#               ['625', array('I', [5])],
#               ['627', array('I', [4])],
#               ['633', array('I', [12])],
#               ['639', array('I', [12])],
#               ['662', array('I', [1])],
#               ['666', array('I', [11])],
#               ['712', array('I', [14])],
#               ['731', array('I', [8])],
#               ['744', array('I', [19])],
#               ['766', array('I', [7])],
#               ['770', array('I', [10])],
#               ['777', array('I', [14])],
#               ['827', array('I', [12])],
#               ['835', array('I', [6])],
#               ['882', array('I', [21])],
#               ['900', array('I', [13])],
#               ['908', array('I', [4])],
#               ['916', array('I', [2])],
#               ['926', array('I', [8])],
#               ['930', array('I', [7])],
#               ['931', array('I', [9, 12])],
#               ['938', array('I', [1])],
#               ['942', array('I', [6])],
#               ['963', array('I', [16])],
#               ['981', array('I', [24])],
#               ['994', array('I', [8, 13])],
#               ['1003', array('I', [3])],
#               ['1008', array('I', [3])],
#               ['1015', array('I', [4])],
#               ['1035', array('I', [3])],
#               ['1040', array('I', [21])],
#               ['1069', array('I', [22])],
#               ['1083', array('I', [1, 12])],
#               ['1084', array('I', [1, 9])],
#               ['1091', array('I', [4])],
#               ['1101', array('I', [10])],
#               ['1105', array('I', [14])],
#               ['1125', array('I', [14])],
#               ['1129', array('I', [12])],
#               ['1153', array('I', [0])],
#               ['1161', array('I', [15])],
#               ['1163', array('I', [9])],
#               ['1166', array('I', [2])],
#               ['1173', array('I', [0])],
#               ['1177', array('I', [19])],
#               ['1179', array('I', [1])],
#               ['1190', array('I', [4])],
#               ['1192', array('I', [5])],
#               ['1213', array('I', [21])],
#               ['1220', array('I', [3])],
#               ['1247', array('I', [12])],
#               ['1261', array('I', [3])],
#               ['1263', array('I', [3])],
#               ['1291', array('I', [0])],
#               ['1296', array('I', [11])],
#               ['1298', array('I', [7])],
#               ['1317', array('I', [8])],
#               ['1342', array('I', [0, 11])],
#               ['1346', array('I', [3])],
#               ['1358', array('I', [13])],
#               ['1362', array('I', [16])],
#               ['1369', array('I', [6])],
#               ['1377', array('I', [4])],
#               ['1378', array('I', [22])],
#               ['1397', array('I', [15, 23])],
#               ['1414', array('I', [5])],
#               ['1431', array('I', [0])],
#               ['1435', array('I', [5])],
#               ['1438', array('I', [12])],
#               ['1448', array('I', [8])],
#               ['1481', array('I', [8])],
#               ['1482', array('I', [22])],
#               ['1483', array('I', [12])],
#               ['1491', array('I', [8])],
#               ['1495', array('I', [15])],
#               ['1505', array('I', [3])],
#               ['1507', array('I', [15])],
#               ['1513', array('I', [13])],
#               ['1520', array('I', [9])],
#               ['1522', array('I', [13])],
#               ['1575', array('I', [17])],
#               ['1596', array('I', [11])],
#               ['1602', array('I', [10])],
#               ['1617', array('I', [6])],
#               ['1630', array('I', [1, 16])],
#               ['1631', array('I', [1])],
#               ['1632', array('I', [1])],
#               ['1633', array('I', [1, 2, 5, 15])],
#               ['1637', array('I', [17])],
#               ['1643', array('I', [10])],
#               ['1663', array('I', [10])],
#               ['1675', array('I', [0, 18])],
#               ['1678', array('I', [8])],
#               ['1687', array('I', [19])],
#               ['1694', array('I', [1])],
#               ['1698', array('I', [7])],
#               ['1710', array('I', [5])],
#               ['1726', array('I', [15])],
#               ['1738', array('I', [11])],
#               ['1748', array('I', [7])],
#               ['1757', array('I', [13])],
#               ['1772', array('I', [5])],
#               ['1774', array('I', [3])],
#               ['1778', array('I', [6])],
#               ['1794', array('I', [5, 10])],
#               ['1799', array('I', [7])],
#               ['1803', array('I', [14])],
#               ['1810', array('I', [0])],
#               ['1822', array('I', [11])],
#               ['1827', array('I', [11])],
#               ['1845', array('I', [24])],
#               ['1851', array('I', [16])],
#               ['1862', array('I', [3])],
#               ['1870', array('I', [12])],
#               ['1878', array('I', [23])],
#               ['1882', array('I', [14])],
#               ['1883', array('I', [26])],
#               ['1895', array('I', [16])],
#               ['1897', array('I', [27])],
#               ['1900', array('I', [22])],
#               ['1901', array('I', [16])],
#               ['1905', array('I', [11])],
#               ['1912', array('I', [14, 15])],
#               ['1943', array('I', [12])],
#               ['1961', array('I', [2])],
#               ['1974', array('I', [15])],
#               ['1976', array('I', [8])],
#               ['1978', array('I', [15])],
#               ['1980', array('I', [7])],
#               ['1984', array('I', [22])],
#               ['2003', array('I', [15])],
#               ['2020', array('I', [18])],
#               ['2025', array('I', [1])],
#               ['2037', array('I', [3])],
#               ['2041', array('I', [10, 12, 14])],
#               ['2043', array('I', [14])],
#               ['2045', array('I', [6])],
#               ['2068', array('I', [3])],
#               ['2073', array('I', [13])],
#               ['2078', array('I', [7])],
#               ['2090', array('I', [8])],
#               ['2095', array('I', [9])],
#               ['2108', array('I', [25])],
#               ['2144', array('I', [0])],
#               ['2193', array('I', [12])],
#               ['2194', array('I', [15])],
#               ['2208', array('I', [3])],
#               ['2217', array('I', [8])],
#               ['2221', array('I', [4])],
#               ['2256', array('I', [0])],
#               ['2260', array('I', [11])],
#               ['2266', array('I', [2])],
#               ['2283', array('I', [4])],
#               ['2296', array('I', [20])],
#               ['2332', array('I', [20])],
#               ['2337', array('I', [1])],
#               ['2338', array('I', [17, 18])],
#               ['2339', array('I', [4])],
#               ['2351', array('I', [9])],
#               ['2393', array('I', [18])]],
#              'work': [['0', array('I', [15])],
#               ['8', array('I', [11])],
#               ['15', array('I', [7])],
#               ['30', array('I', [16])],
#               ['118', array('I', [12])],
#               ['128', array('I', [2])],
#               ['347', array('I', [9])],
#               ['349', array('I', [20])],
#               ['353', array('I', [13])],
#               ['371', array('I', [3])],
#               ['383', array('I', [4, 13])],
#               ['402', array('I', [3])],
#               ['428', array('I', [7])],
#               ['433', array('I', [4])],
#               ['462', array('I', [17])],
#               ['473', array('I', [8])],
#               ['482', array('I', [11])],
#               ['492', array('I', [9])],
#               ['530', array('I', [19])],
#               ['568', array('I', [3])],
#               ['599', array('I', [17])],
#               ['611', array('I', [8])],
#               ['612', array('I', [26])],
#               ['614', array('I', [23])],
#               ['630', array('I', [6])],
#               ['639', array('I', [3])],
#               ['661', array('I', [19])],
#               ['681', array('I', [9])],
#               ['691', array('I', [0, 12])],
#               ['694', array('I', [2])],
#               ['696', array('I', [6, 11])],
#               ['699', array('I', [8, 19])],
#               ['742', array('I', [22])],
#               ['776', array('I', [10])],
#               ['801', array('I', [20])],
#               ['803', array('I', [0, 4, 6])],
#               ['873', array('I', [4])],
#               ['882', array('I', [19])],
#               ['954', array('I', [2])],
#               ['956', array('I', [14])],
#               ['977', array('I', [29])],
#               ['990', array('I', [6])],
#               ['1032', array('I', [10])],
#               ['1033', array('I', [9])],
#               ['1076', array('I', [1])],
#               ['1085', array('I', [7])],
#               ['1089', array('I', [2])],
#               ['1104', array('I', [2])],
#               ['1115', array('I', [2, 10])],
#               ['1119', array('I', [3])],
#               ['1121', array('I', [17, 18])],
#               ['1124', array('I', [8, 13])],
#               ['1144', array('I', [16])],
#               ['1146', array('I', [7])],
#               ['1200', array('I', [17])],
#               ['1228', array('I', [9])],
#               ['1232', array('I', [20])],
#               ['1258', array('I', [10])],
#               ['1267', array('I', [16])],
#               ['1268', array('I', [4, 10])],
#               ['1279', array('I', [11])],
#               ['1289', array('I', [8])],
#               ['1298', array('I', [5])],
#               ['1317', array('I', [5])],
#               ['1346', array('I', [22])],
#               ['1347', array('I', [10])],
#               ['1351', array('I', [10])],
#               ['1353', array('I', [8])],
#               ['1358', array('I', [3])],
#               ['1361', array('I', [13])],
#               ['1363', array('I', [4])],
#               ['1365', array('I', [3])],
#               ['1378', array('I', [3])],
#               ['1389', array('I', [5])],
#               ['1401', array('I', [7])],
#               ['1446', array('I', [8])],
#               ['1450', array('I', [3])],
#               ['1452', array('I', [1])],
#               ['1471', array('I', [9, 24])],
#               ['1473', array('I', [9])],
#               ['1485', array('I', [3])],
#               ['1499', array('I', [22])],
#               ['1513', array('I', [10])],
#               ['1514', array('I', [20])],
#               ['1537', array('I', [4])],
#               ['1544', array('I', [0])],
#               ['1559', array('I', [8])],
#               ['1563', array('I', [4])],
#               ['1566', array('I', [7])],
#               ['1611', array('I', [15])],
#               ['1615', array('I', [8])],
#               ['1634', array('I', [12])],
#               ['1669', array('I', [2, 5])],
#               ['1689', array('I', [8])],
#               ['1697', array('I', [5])],
#               ['1700', array('I', [15])],
#               ['1737', array('I', [14])],
#               ['1759', array('I', [4])],
#               ['1763', array('I', [10])],
#               ['1764', array('I', [5])],
#               ['1767', array('I', [11])],
#               ['1779', array('I', [2])],
#               ['1790', array('I', [6])],
#               ['1798', array('I', [4])],
#               ['1810', array('I', [12])],
#               ['1919', array('I', [9])],
#               ['1979', array('I', [11])],
#               ['1981', array('I', [12])],
#               ['2020', array('I', [0])],
#               ['2026', array('I', [5])],
#               ['2141', array('I', [3])],
#               ['2150', array('I', [5])],
#               ['2198', array('I', [4])],
#               ['2208', array('I', [12])],
#               ['2210', array('I', [8])],
#               ['2224', array('I', [7, 16])],
#               ['2225', array('I', [17])],
#               ['2227', array('I', [1])],
#               ['2228', array('I', [4])],
#               ['2229', array('I', [11])],
#               ['2247', array('I', [21])],
#               ['2249', array('I', [19])],
#               ['2278', array('I', [21])],
#               ['2284', array('I', [9])],
#               ['2288', array('I', [12])],
#               ['2296', array('I', [19])],
#               ['2329', array('I', [17])],
#               ['2330', array('I', [1])],
#               ['2332', array('I', [8])],
#               ['2339', array('I', [6])]],
#              'within': [['0', array('I', [16])],
#               ['235', array('I', [17, 25])],
#               ['343', array('I', [14])],
#               ['352', array('I', [9])],
#               ['1248', array('I', [7])],
#               ['1275', array('I', [5])],
#               ['1533', array('I', [13])],
#               ['1554', array('I', [6])],
#               ['1599', array('I', [14])],
#               ['1601', array('I', [18])],
#               ['1642', array('I', [27])],
#               ['2059', array('I', [13])],
#               ['2102', array('I', [18])],
#               ['2180', array('I', [4])],
#               ['2183', array('I', [1])],
#               ['2194', array('I', [0])],
#               ['2234', array('I', [3])]],
#              'public': [['0', array('I', [17])],
#               ['153', array('I', [18])],
#               ['186', array('I', [16])],
#               ['209', array('I', [30])],
#               ['294', array('I', [17])],
#               ['314', array('I', [6])],
#               ['392', array('I', [3])],
#               ['422', array('I', [8])],
#               ['434', array('I', [26])],
#               ['450', array('I', [16])],
#               ['497', array('I', [11])],
#               ['572', array('I', [19])],
#               ['578', array('I', [12])],
#               ['593', array('I', [16])],
#               ['602', array('I', [4])],
#               ['672', array('I', [3])],
#               ['714', array('I', [6])],
#               ['761', array('I', [5])],
#               ['815', array('I', [4])],
#               ['820', array('I', [4])],
#               ['831', array('I', [20])],
#               ['860', array('I', [4])],
#               ['890', array('I', [20])],
#               ['1015', array('I', [22])],
#               ['1017', array('I', [11])],
#               ['1094', array('I', [14])],
#               ['1107', array('I', [2])],
#               ['1121', array('I', [12])],
#               ['1156', array('I', [8])],
#               ['1202', array('I', [17])],
#               ['1248', array('I', [17])],
#               ['1283', array('I', [11])],
#               ['1325', array('I', [21])],
#               ['1337', array('I', [10])],
#               ['1362', array('I', [1])],
#               ['1377', array('I', [12])],
#               ['1419', array('I', [10])],
#               ['1423', array('I', [9])],
#               ['1431', array('I', [22])],
#               ['1448', array('I', [6])],
#               ['1462', array('I', [16])],
#               ['1499', array('I', [16])],
#               ['1633', array('I', [12])],
#               ['1638', array('I', [11])],
#               ['1657', array('I', [5])],
#               ['1697', array('I', [13])],
#               ['1737', array('I', [19])],
#               ['1738', array('I', [15])],
#               ['1757', array('I', [16])],
#               ['1796', array('I', [21])],
#               ['1829', array('I', [21])],
#               ['1850', array('I', [2])],
#               ['1873', array('I', [14])],
#               ['1896', array('I', [9])],
#               ['1902', array('I', [14])],
#               ['1920', array('I', [4])],
#               ['1921', array('I', [17])],
#               ['2013', array('I', [16])],
#               ['2023', array('I', [21])],
#               ['2036', array('I', [12])],
#               ['2050', array('I', [5])],
#               ['2054', array('I', [10])],
#               ['2056', array('I', [3])],
#               ['2065', array('I', [12])],
#               ['2072', array('I', [7])],
#               ['2073', array('I', [16])],
#               ['2086', array('I', [23])],
#               ['2099', array('I', [14])],
#               ['2117', array('I', [12])],
#               ['2120', array('I', [12])],
#               ['2138', array('I', [15])],
#               ['2200', array('I', [0])],
#               ['2203', array('I', [14])],
#               ['2260', array('I', [19])],
#               ['2265', array('I', [5])],
#               ['2266', array('I', [25])],
#               ['2314', array('I', [12])],
#               ['2378', array('I', [13])],
#               ['2380', array('I', [3])]],
#              'health': [['0', array('I', [18])],
#               ['1', array('I', [2, 10])],
#               ['2', array('I', [11, 29])],
#               ['12', array('I', [12])],
#               ['15', array('I', [8])],
#               ['19', array('I', [24])],
#               ['23', array('I', [21])],
#               ['27', array('I', [28])],
#               ['28', array('I', [9, 14, 20])],
#               ['29', array('I', [2, 5, 8, 19])],
#               ['33', array('I', [8])],
#               ['34', array('I', [12, 20])],
#               ['35', array('I', [12])],
#               ['38', array('I', [11])],
#               ['40', array('I', [9])],
#               ['41', array('I', [13])],
#               ['42', array('I', [6])],
#               ['50', array('I', [8])],
#               ['52', array('I', [6])],
#               ['56', array('I', [10])],
#               ['62', array('I', [8])],
#               ['67', array('I', [15])],
#               ['71', array('I', [11, 17])],
#               ['72', array('I', [10, 17, 25])],
#               ['74', array('I', [6])],
#               ['76', array('I', [9])],
#               ['83', array('I', [10])],
#               ['111', array('I', [7])],
#               ['114', array('I', [13])],
#               ['134', array('I', [24])],
#               ['135', array('I', [4])],
#               ['136', array('I', [16])],
#               ['139', array('I', [16, 22])],
#               ['147', array('I', [11])],
#               ['148', array('I', [6])],
#               ['149', array('I', [9])],
#               ['152', array('I', [1])],
#               ['153', array('I', [19])],
#               ['154', array('I', [13])],
#               ['156', array('I', [9])],
#               ['166', array('I', [15])],
#               ['185', array('I', [17])],
#               ['186', array('I', [17])],
#               ['189', array('I', [16])],
#               ['208', array('I', [4])],
#               ['209', array('I', [4, 31])],
#               ['210', array('I', [4])],
#               ['211', array('I', [4])],
#               ['212', array('I', [13])],
#               ['215', array('I', [6, 9])],
#               ['219', array('I', [8])],
#               ['235', array('I', [33])],
#               ['236', array('I', [10, 17])],
#               ['253', array('I', [6])],
#               ['255', array('I', [5])],
#               ['265', array('I', [4])],
#               ['268', array('I', [5])],
#               ['277', array('I', [14])],
#               ['286', array('I', [11])],
#               ['287', array('I', [9, 15])],
#               ['289', array('I', [7])],
#               ['290', array('I', [0, 9, 16])],
#               ['291', array('I', [3, 12, 22])],
#               ['293', array('I', [2, 8])],
#               ['294', array('I', [13, 18, 26])],
#               ['296', array('I', [6])],
#               ['297', array('I', [11, 16, 18])],
#               ['298', array('I', [8, 24])],
#               ['299', array('I', [11])],
#               ['306', array('I', [3])],
#               ['314', array('I', [7])],
#               ['317', array('I', [3, 11])],
#               ['319', array('I', [2])],
#               ['330', array('I', [16])],
#               ['336', array('I', [16])],
#               ['337', array('I', [4])],
#               ['346', array('I', [15])],
#               ['349', array('I', [22])],
#               ['351', array('I', [8])],
#               ['354', array('I', [7])],
#               ['355', array('I', [7])],
#               ['395', array('I', [2])],
#               ['398', array('I', [6])],
#               ['400', array('I', [9])],
#               ['408', array('I', [6, 10])],
#               ['409', array('I', [1])],
#               ['410', array('I', [5])],
#               ['413', array('I', [5, 14])],
#               ['415', array('I', [12, 14])],
#               ['418', array('I', [6])],
#               ['420', array('I', [18])],
#               ['422', array('I', [9])],
#               ['423', array('I', [12])],
#               ['425', array('I', [5])],
#               ['426', array('I', [7])],
#               ['427', array('I', [5, 11])],
#               ['429', array('I', [16])],
#               ['432', array('I', [8])],
#               ['434', array('I', [19, 24])],
#               ['436', array('I', [15])],
#               ['440', array('I', [4, 23])],
#               ['443', array('I', [12])],
#               ['444', array('I', [25])],
#               ['451', array('I', [21])],
#               ['453', array('I', [19])],
#               ['454', array('I', [23])],
#               ['458', array('I', [9, 13])],
#               ['459', array('I', [3, 7, 12, 16, 18, 21])],
#               ['462', array('I', [8, 12])],
#               ['494', array('I', [14])],
#               ['496', array('I', [15])],
#               ['497', array('I', [12])],
#               ['499', array('I', [7, 12])],
#               ['502', array('I', [25])],
#               ['520', array('I', [10])],
#               ['521', array('I', [0])],
#               ['525', array('I', [21])],
#               ['528', array('I', [14])],
#               ['529', array('I', [22])],
#               ['530', array('I', [24])],
#               ['537', array('I', [7])],
#               ['539', array('I', [19])],
#               ['541', array('I', [6])],
#               ['543', array('I', [11])],
#               ['545', array('I', [5])],
#               ['546', array('I', [1])],
#               ['547', array('I', [10])],
#               ['548', array('I', [10])],
#               ['555', array('I', [21])],
#               ['556', array('I', [11])],
#               ['558', array('I', [10, 17])],
#               ['560', array('I', [6, 9, 12])],
#               ['565', array('I', [6, 19])],
#               ['568', array('I', [5])],
#               ['570', array('I', [16])],
#               ['571', array('I', [9, 16])],
#               ['572', array('I', [11, 20])],
#               ['573', array('I', [7, 19])],
#               ['577', array('I', [20])],
#               ['578', array('I', [13])],
#               ['584', array('I', [20])],
#               ['586', array('I', [6])],
#               ['588', array('I', [6, 12])],
#               ['592', array('I', [6])],
#               ['593', array('I', [17])],
#               ['594', array('I', [10])],
#               ['596', array('I', [22])],
#               ['598', array('I', [1])],
#               ['599', array('I', [15])],
#               ['602', array('I', [5])],
#               ['605', array('I', [16])],
#               ['606', array('I', [1])],
#               ['610', array('I', [14])],
#               ['611', array('I', [11, 20])],
#               ['612', array('I', [13, 15, 18, 23])],
#               ['615', array('I', [8, 14, 22])],
#               ['616', array('I', [10, 15, 23, 27])],
#               ['617', array('I', [23])],
#               ['618', array('I', [9])],
#               ['621', array('I', [3])],
#               ['625', array('I', [10])],
#               ['627', array('I', [2, 8])],
#               ['633', array('I', [5])],
#               ['634', array('I', [10])],
#               ['636', array('I', [5, 14])],
#               ['637', array('I', [23])],
#               ['644', array('I', [9])],
#               ['646', array('I', [17])],
#               ['650', array('I', [8])],
#               ['653', array('I', [10])],
#               ['656', array('I', [12])],
#               ['657', array('I', [3, 7, 13])],
#               ['661', array('I', [5, 16, 20])],
#               ['662', array('I', [12])],
# ...
#               ['397', array('I', [8])],
#               ['792', array('I', [5])],
#               ['883', array('I', [27])],
#               ['1175', array('I', [14])],
#               ['1372', array('I', [19])],
#               ['1712', array('I', [14, 21])],
#               ['1729', array('I', [11])],
#               ['1811', array('I', [6, 11])],
#               ['2021', array('I', [1])],
#               ['2023', array('I', [13])],
#               ['2024', array('I', [2, 8])],
#               ['2221', array('I', [11])],
#               ['2222', array('I', [8])],
#               ['2223', array('I', [11])],
#               ['2239', array('I', [11])],
#               ['2240', array('I', [9])],
#               ['2297', array('I', [15])]],
#              'donor': [['141', array('I', [8])],
#               ['555', array('I', [6])],
#               ['557', array('I', [5])],
#               ['616', array('I', [7])],
#               ['786', array('I', [15])],
#               ['790', array('I', [7])],
#               ['837', array('I', [16])],
#               ['984', array('I', [19])],
#               ['1029', array('I', [7])],
#               ['1032', array('I', [8])],
#               ['1126', array('I', [4])],
#               ['1164', array('I', [14])],
#               ['1495', array('I', [11])],
#               ['1504', array('I', [12])]],
#              'done': [['141', array('I', [13])],
#               ['230', array('I', [4])],
#               ['383', array('I', [2])],
#               ['387', array('I', [16])],
#               ['405', array('I', [7])],
#               ['449', array('I', [12])],
#               ['555', array('I', [11])],
#               ['737', array('I', [15])],
#               ['989', array('I', [4])],
#               ['1169', array('I', [5])],
#               ['1679', array('I', [0])],
#               ['1862', array('I', [8])],
#               ['1892', array('I', [27])],
#               ['2028', array('I', [9])],
#               ['2376', array('I', [5])]],
#              'far': [['141', array('I', [14])],
#               ['194', array('I', [12])],
#               ['206', array('I', [2])],
#               ['293', array('I', [4])],
#               ['493', array('I', [5])],
#               ['750', array('I', [4])],
#               ['754', array('I', [1])],
#               ['782', array('I', [9])],
#               ['808', array('I', [2])],
#               ['865', array('I', [12])],
#               ['965', array('I', [20])],
#               ['1215', array('I', [1])],
#               ['1265', array('I', [2])],
#               ['1282', array('I', [2])],
#               ['1348', array('I', [1])],
#               ['1416', array('I', [6])],
#               ['1475', array('I', [6])],
#               ['1479', array('I', [5])],
#               ['1494', array('I', [16])],
#               ['1511', array('I', [1])],
#               ['1515', array('I', [21])],
#               ['1538', array('I', [7])],
#               ['1626', array('I', [4])],
#               ['1639', array('I', [10])],
#               ['1659', array('I', [4])],
#               ['1698', array('I', [8])],
#               ['1758', array('I', [15])],
#               ['1895', array('I', [28])],
#               ['1969', array('I', [12])],
#               ['2082', array('I', [7])],
#               ['2099', array('I', [6])],
#               ['2119', array('I', [9])],
#               ['2153', array('I', [4])],
#               ['2340', array('I', [9])],
#               ['2359', array('I', [10])],
#               ['2381', array('I', [7])]],
#              '7njlspvtj': [['141', array('I', [20])]],
#              'suppress': [['142', array('I', [5])],
#               ['289', array('I', [12])],
#               ['2129', array('I', [20])]],
#              'transmiss': [['142', array('I', [6])],
#               ['207', array('I', [25])],
#               ['284', array('I', [10])],
#               ['496', array('I', [5])],
#               ['578', array('I', [8])],
#               ['758', array('I', [12])],
#               ['831', array('I', [7])],
#               ['864', array('I', [23])],
#               ['1179', array('I', [21])],
#               ['1325', array('I', [9])],
#               ['1416', array('I', [4])],
#               ['1430', array('I', [11])],
#               ['1596', array('I', [7])],
#               ['1597', array('I', [7])],
#               ['1600', array('I', [6])],
#               ['1602', array('I', [6])],
#               ['1609', array('I', [13])],
#               ['1633', array('I', [19])],
#               ['1640', array('I', [5])],
#               ['1758', array('I', [6])],
#               ['1784', array('I', [15])],
#               ['1829', array('I', [9])],
#               ['1915', array('I', [28])],
#               ['2051', array('I', [21])],
#               ['2055', array('I', [10])],
#               ['2085', array('I', [7])],
#               ['2086', array('I', [6])],
#               ['2205', array('I', [1])],
#               ['2206', array('I', [8])],
#               ['2287', array('I', [6])],
#               ['2341', array('I', [4])],
#               ['2359', array('I', [7])],
#               ['2378', array('I', [9])],
#               ['2379', array('I', [13, 16, 19])],
#               ['2380', array('I', [11])],
#               ['2381', array('I', [3])]],
#              'exposur': [['142', array('I', [8])],
#               ['591', array('I', [1])],
#               ['596', array('I', [2])],
#               ['1720', array('I', [18])]],
#              'mortal': [['142', array('I', [9])],
#               ['565', array('I', [13])],
#               ['773', array('I', [9])],
#               ['783', array('I', [12])],
#               ['1588', array('I', [14])],
#               ['1963', array('I', [16])],
#               ['2296', array('I', [13])]],
#              'morbid': [['142', array('I', [11])]],
#              'counter': [['142', array('I', [12])],
#               ['478', array('I', [0])],
#               ['930', array('I', [19])],
#               ['2067', array('I', [0])]],
#              'misinform': [['142', array('I', [13])],
#               ['329', array('I', [14])],
#               ['336', array('I', [2])],
#               ['338', array('I', [18])],
#               ['497', array('I', [4])],
#               ['831', array('I', [26])],
#               ['2276', array('I', [6])]],
#              'tool': [['142', array('I', [18])],
#               ['186', array('I', [7])],
#               ['213', array('I', [3, 7])],
#               ['216', array('I', [5])],
#               ['219', array('I', [15])],
#               ['263', array('I', [11])],
#               ['272', array('I', [11])],
#               ['426', array('I', [13])],
#               ['441', array('I', [16])],
#               ['506', array('I', [22])],
#               ['518', array('I', [5])],
#               ['534', array('I', [2])],
#               ['577', array('I', [12])],
#               ['578', array('I', [5, 14, 17])],
#               ['602', array('I', [8])],
#               ['635', array('I', [14])],
#               ['797', array('I', [12])],
#               ['835', array('I', [4])],
#               ['849', array('I', [18])],
#               ['863', array('I', [5])],
#               ['956', array('I', [10])],
#               ['963', array('I', [21])],
#               ['994', array('I', [12])],
#               ['1003', array('I', [7])],
#               ['1018', array('I', [8])],
#               ['1071', array('I', [0, 11])],
#               ['1084', array('I', [12])],
#               ['1142', array('I', [18])],
#               ['1165', array('I', [9])],
#               ['1224', array('I', [5])],
#               ['1236', array('I', [22])],
#               ['1246', array('I', [19])],
#               ['1263', array('I', [8])],
#               ['1397', array('I', [3])],
#               ['1422', array('I', [5])],
#               ['1499', array('I', [5, 8])],
#               ['1565', array('I', [20])],
#               ['1630', array('I', [8])],
#               ['1631', array('I', [10])],
#               ['1643', array('I', [9])],
#               ['1677', array('I', [17])],
#               ['1678', array('I', [4])],
#               ['1694', array('I', [10])],
#               ['1778', array('I', [8])],
#               ['1779', array('I', [14])],
#               ['1897', array('I', [16, 24])],
#               ['1901', array('I', [15])],
#               ['1905', array('I', [10])],
#               ['1920', array('I', [6])],
#               ['1921', array('I', [9])],
#               ['1928', array('I', [13])],
#               ['1948', array('I', [14])],
#               ['2035', array('I', [24])],
#               ['2036', array('I', [20])],
#               ['2052', array('I', [9])],
#               ['2065', array('I', [11])],
#               ['2113', array('I', [28])],
#               ['2125', array('I', [28])],
#               ['2193', array('I', [15])],
#               ['2194', array('I', [14])],
#               ['2251', array('I', [12])],
#               ['2378', array('I', [5])]],
#              'zf3rtjjyul': [['142', array('I', [27])]],
#              'vivo': [['143', array('I', [2])],
#               ['1367', array('I', [2])],
#               ['1464', array('I', [3])],
#               ['1557', array('I', [3])]],
#              'atenc': [['143', array('I', [3])]],
#              'salud': [['143', array('I', [4])],
#               ['824', array('I', [8])],
#               ['1328', array('I', [3])],
#               ['1464', array('I', [4])]],
#              'toda': [['143', array('I', [6])]],
#              'persona': [['143', array('I', [7])]],
#              'hag': [['143', array('I', [8])]],
#              'mosla': [['143', array('I', [9])]],
#              'realidad': [['143', array('I', [10])]],
#              'sizv51f3qh': [['143', array('I', [13])]],
#              '70': [['144', array('I', [0])],
#               ['164', array('I', [3])],
#               ['167', array('I', [12])],
#               ['192', array('I', [25])],
#               ['242', array('I', [3])],
#               ['322', array('I', [18])],
#               ['438', array('I', [16])],
#               ['484', array('I', [9])],
#               ['490', array('I', [8])],
#               ['515', array('I', [8])],
#               ['580', array('I', [15])],
#               ['583', array('I', [15])],
#               ['702', array('I', [12])],
#               ['727', array('I', [4])],
#               ['755', array('I', [12])],
#               ['833', array('I', [11])],
#               ['852', array('I', [9])],
#               ['853', array('I', [17])],
#               ['864', array('I', [18])],
#               ['866', array('I', [25])],
#               ['1151', array('I', [17])],
#               ['1347', array('I', [23])],
#               ['1622', array('I', [17])],
#               ['1626', array('I', [19])],
#               ['1627', array('I', [20])],
#               ['1795', array('I', [25])],
#               ['1845', array('I', [2])],
#               ['1848', array('I', [1])],
#               ['1863', array('I', [14])],
#               ['1879', array('I', [12])],
#               ['1882', array('I', [20])],
#               ['1884', array('I', [13])],
#               ['1895', array('I', [9])],
#               ['1904', array('I', [8])],
#               ['2112', array('I', [18])],
#               ['2141', array('I', [15])],
#               ['2198', array('I', [10])],
#               ['2226', array('I', [23])],
#               ['2235', array('I', [11])],
#               ['2273', array('I', [8])]],
#              'expenditur': [['144', array('I', [3])]],
#              'alloc': [['144', array('I', [5])],
#               ['191', array('I', [12])],
#               ['302', array('I', [19])],
#               ['509', array('I', [25])],
#               ['510', array('I', [23])],
#               ['511', array('I', [19])],
#               ['514', array('I', [2])],
#               ['520', array('I', [2])],
#               ['1229', array('I', [13])],
#               ['1236', array('I', [4])],
#               ['1922', array('I', [6])]],
#              'middl': [['144', array('I', [8])],
#               ['192', array('I', [26])],
#               ['194', array('I', [4])],
#               ['305', array('I', [19])],
#               ['438', array('I', [19])],
#               ['504', array('I', [9])],
#               ['505', array('I', [18])],
#               ['583', array('I', [16])],
#               ['606', array('I', [8])],
#               ['672', array('I', [14])],
#               ['755', array('I', [15])],
#               ['839', array('I', [6])],
#               ['853', array('I', [19])],
#               ['854', array('I', [13])],
#               ['1151', array('I', [21])],
#               ['1242', array('I', [14])],
#               ['1511', array('I', [13])],
#               ['1627', array('I', [21])],
#               ['1795', array('I', [26])],
#               ['1814', array('I', [7])],
#               ['1843', array('I', [7])],
#               ['1848', array('I', [5])],
#               ['1882', array('I', [24])],
#               ['1884', array('I', [16])],
#               ['1895', array('I', [13])],
#               ['1904', array('I', [12])],
#               ['2001', array('I', [27])],
#               ['2043', array('I', [28])],
#               ['2127', array('I', [14])],
#               ['2138', array('I', [11])],
#               ['2189', array('I', [16])]],
#              'incom': [['144', array('I', [9, 14])],
#               ['194', array('I', [5, 14])],
#               ['305', array('I', [20])],
#               ['438', array('I', [20])],
#               ['504', array('I', [10])],
#               ['534', array('I', [12, 20])],
#               ['581', array('I', [1])],
#               ['606', array('I', [9])],
#               ['750', array('I', [26])],
#               ['833', array('I', [4])],
#               ['839', array('I', [7])],
#               ['841', array('I', [9])],
#               ['848', array('I', [7, 24])],
#               ['849', array('I', [15])],
#               ['850', array('I', [4])],
#               ['851', array('I', [6, 9])],
#               ['852', array('I', [4])],
#               ['854', array('I', [14])],
#               ['972', array('I', [2, 14])],
#               ['1052', array('I', [8, 14])],
#               ['1054', array('I', [21, 27])],
#               ['1107', array('I', [10])],
#               ['1242', array('I', [15])],
#               ['1245', array('I', [10])],
#               ['1326', array('I', [9])],
#               ['1344', array('I', [13])],
#               ['1348', array('I', [10])],
#               ['1507', array('I', [3, 22, 27])],
#               ['1508', array('I', [5, 18])],
#               ['1511', array('I', [14])],
#               ['1636', array('I', [4, 9])],
#               ['1674', array('I', [20])],
#               ['1803', array('I', [9])],
#               ['1814', array('I', [8])],
#               ['1843', array('I', [8])],
#               ['1845', array('I', [20])],
#               ['1848', array('I', [6, 15, 24])],
#               ['1849', array('I', [13, 23])],
#               ['1850', array('I', [9])],
#               ['1926', array('I', [8, 20])],
#               ['2001', array('I', [28])],
#               ['2035', array('I', [7])],
#               ['2043', array('I', [29])],
#               ['2053', array('I', [3])],
#               ['2127', array('I', [15])],
#               ['2138', array('I', [12])],
#               ['2189', array('I', [17])],
#               ['2261', array('I', [12])],
#               ['2262', array('I', [10])],
#               ['2339', array('I', [25])]],
#              'vs': [['144', array('I', [11])], ['1166', array('I', [12])]],
#              '35': [['144', array('I', [12])], ['2317', array('I', [9])]],
#              'jdltswcubb': [['144', array('I', [21])]],
#              'colleagu': [['145', array('I', [2])],
#               ['349', array('I', [7])],
#               ['676', array('I', [5])],
#               ['737', array('I', [14])],
#               ['748', array('I', [9])],
#               ['1196', array('I', [6])],
#               ['1264', array('I', [1])],
#               ['1297', array('I', [4])],
#               ['1593', array('I', [6])],
#               ['2352', array('I', [9])],
#               ['2360', array('I', [6])],
#               ['2361', array('I', [5])]],
#              'alisonbruni': [['145', array('I', [5])]],
#              'atla': [['145', array('I', [10])],
#               ['147', array('I', [4])],
#               ['154', array('I', [5])],
#               ['156', array('I', [10])]],
#              ...})

# %%
def rank_documents(terms, docs, index, idf, tf):
    """
    Perform the ranking of the results of a search based on the tf-idf weights
    
    Argument:
    terms -- list of query terms
    docs -- list of documents, to rank, matching the query
    index -- inverted index data structure
    idf -- inverted document frequencies
    tf -- term frequencies
    
    Returns:
    Print the list of ranked documents
    """

    # I'm interested only on the element of the docVector corresponding to the query terms 
    # The remaining elements would became 0 when multiplied to the query_vector
    doc_vectors = defaultdict(lambda: [0] * len(terms)) # I call doc_vectors[k] for a nonexistent key k, the key-value pair (k,[0]*len(terms)) will be automatically added to the dictionary
    query_vector = [0] * len(terms)

    # compute the norm for the query tf
    query_terms_count = collections.Counter(terms)  # get the frequency of each term in the query. 
    # Example: collections.Counter(["hello","hello","world"]) --> Counter({'hello': 2, 'world': 1})
    #HINT: use when computing tf for query_vector

    query_norm = la.norm(list(query_terms_count.values()))

    for termIndex, term in enumerate(terms):  #termIndex is the index of the term in the query
        if term not in index:
            continue
  
        ## Compute tf*idf(normalize TF as done with documents)
        query_vector[termIndex] =  query_terms_count[term]/len(terms)*idf[term]

        # Generate doc_vectors for matching docs
        for doc_index, (doc, postings) in enumerate(index[term]):
            # Example of [doc_index, (doc, postings)]
            # 0 (26, array('I', [1, 4, 12, 15, 22, 28, 32, 43, 51, 68, 333, 337]))
            # 1 (33, array('I', [26, 33, 57, 71, 87, 104, 109]))
            # term is in doc 26 in positions 1,4, .....
            # term is in doc 33 in positions 26,33, .....

            #tf[term][0] will contain the tf of the term "term" in the doc 26            
            if doc in docs:
                doc_vectors[doc][termIndex] = tf[term][doc_index] * idf[term]  # TODO: check if multiply for idf

    # Calculate the score of each doc 
    # compute the cosine similarity between queyVector and each docVector:
    # HINT: you can use the dot product because in case of normalized vectors it corresponds to the cosine similarity
    # see np.dot
    
    doc_scores=[[np.dot(curDocVec, query_vector), doc] for doc, curDocVec in doc_vectors.items() ]
    doc_scores.sort(reverse=True)
    result_docs = [x[1] for x in doc_scores]
    #print document titles instead if document id's
    #result_docs=[ title_index[x] for x in result_docs ]
    if len(result_docs) == 0:
        print("No results found, try again")
        query = input()
        docs = search_tf_idf(query, index)
    #print ('\n'.join(result_docs), '\n')
    return result_docs

# %%
def search_tf_idf(query, index):
    """
    output is the list of documents that contain any of the query terms. 
    So, we will get the list of documents for each query term, and take the union of them.
    """
    query = build_terms(query)
    docs = set()
    for term in query:
        try:
            # store in term_docs the ids of the docs that contain "term"                        
            term_docs=[posting[0] for posting in index[term]]
            
            # docs = docs Union term_docs
            docs = docs.union(term_docs)
        except:
            #term is not in index
            pass
    docs = list(docs)
    ranked_docs = rank_documents(query, docs, index, idf, tf)
    return ranked_docs

# %%
print("Insert your query (i.e.: Computer Science):\n")
query = input()
ranked_docs = search_tf_idf(query, index)
top = 10

print("\n======================\nTop {} results out of {} for the searched query:\n".format(top, len(ranked_docs)))
for d_id in ranked_docs[:top]:
    info_list = ["tweet","username","date","hashtags","likes","retweets","url"]
    print("DOC", d_id, "has been retrieved")
    for i in info:
        print(i,":",docs_info[d_id][i])
    print("\n")
# Out:
# Insert your query (i.e.: Computer Science):
#
# civid HELP
#
# ======================
# Top 10 results out of 151 for the searched query:
#
# DOC 1868 has been retrieved
# tweet : Getting vaccinated 💉 against #COVID19 helps protect you from getting sick. https://t.co/9Ad3uW0NsN
# username : World Health Organization (WHO)
# date : Wed Jul 21 15:14:10 +0000 2021
# hashtags : [{'text': 'COVID19', 'indices': [29, 37]}]
# likes : 366
# retweets : 155
# url : https://twitter.com/WHO/status/1417865492333621253/photo/1
#
#
# DOC 1469 has been retrieved
# tweet : Getting vaccinated 💉 can help protect you and those around you from #COVID19 ⬇️ https://t.co/3GrojOAWT6
# username : World Health Organization (WHO)
# date : Fri Aug 06 10:29:12 +0000 2021
# hashtags : [{'text': 'COVID19', 'indices': [68, 76]}]
# likes : 253
# retweets : 117
# url : https://twitter.com/WHO/status/1423591981456838656/photo/1
#
#
# DOC 61 has been retrieved
# tweet : RT @WHOPhilippines: Vaccines can’t stop #COVID19 alone, but by doing it all we can help protect ourselves and our loved ones against COVID-…
# username : World Health Organization (WHO)
# date : Mon Oct 11 04:39:10 +0000 2021
# hashtags : [{'text': 'COVID19', 'indices': [40, 48]}]
# likes : 0
# retweets : 71
# url : https://twitter.com/WHO/status/1447421491428143106
#
#
# DOC 1578 has been retrieved
# tweet : RT @WHOWPRO: It’s #WorldBreastfeedingWeek!
#
# Breast milk can help your child have a healthier future.
#
#  🤱🏽 Breastfed babies:
#
# ✅Are l…
# username : World Health Organization (WHO)
# date : Sun Aug 01 16:28:43 +0000 2021
# hashtags : [{'text': 'WorldBreastfeedingWeek', 'indices': [18, 41]}]
# likes : 0
# retweets : 62
# url : https://twitter.com/WHO/status/1421870519071162373
#
#
# DOC 1332 has been retrieved
# tweet : RT @WHOWPRO: Encourage your loved ones to get vaccinated against #COVID19. Help them register and get to the vaccination site.
#
# Vaccination…
# username : World Health Organization (WHO)
# date : Fri Aug 13 15:37:03 +0000 2021
# hashtags : [{'text': 'COVID19', 'indices': [65, 73]}]
# likes : 0
# retweets : 48
# url : https://twitter.com/WHO/status/1426206173225787392
#
#
# DOC 805 has been retrieved
# tweet : RT @DrTedros: If you know someone who may be considering #suicide, here is some advice on how to reach out and offer help ⬇️
#
# #WorldSuicide…
# username : World Health Organization (WHO)
# date : Fri Sep 10 19:51:09 +0000 2021
# hashtags : [{'text': 'suicide', 'indices': [57, 65]}]
# likes : 0
# retweets : 103
# url : https://twitter.com/WHO/status/1436416976642056193
#
#
# DOC 80 has been retrieved
# tweet : Do you feel like life is not worth living?
#
# #LetsTalk about how and where to ask for help.
#
# #WorldMentalHealthDay https://t.co/YxlOa7JGD1
# username : World Health Organization (WHO)
# date : Sun Oct 10 15:54:07 +0000 2021
# hashtags : [{'text': 'LetsTalk', 'indices': [45, 54]}, {'text': 'WorldMentalHealthDay', 'indices': [94, 115]}]
# likes : 171
# retweets : 71
# url : https://twitter.com/WHO/status/1447228961495343109/photo/1
#
#
# DOC 75 has been retrieved
# tweet : RT @DrTedros: Thank you, @RGrosjean, for joining @WHO's #WorldMentalHealthDay campaign and encouraging everyone to open up, seek help and o…
# username : World Health Organization (WHO)
# date : Sun Oct 10 17:23:52 +0000 2021
# hashtags : [{'text': 'WorldMentalHealthDay', 'indices': [56, 77]}]
# likes : 0
# retweets : 86
# url : https://twitter.com/WHO/status/1447251550716444676
#
#
# DOC 69 has been retrieved
# tweet : RT @DrTedros: Thank you, @FLOTUS, for supporting the #WorldMentalHealthDay campaign and encouraging people to seek help. It's ok not to be…
# username : World Health Organization (WHO)
# date : Sun Oct 10 19:57:02 +0000 2021
# hashtags : [{'text': 'WorldMentalHealthDay', 'indices': [53, 74]}]
# likes : 0
# retweets : 46
# url : https://twitter.com/WHO/status/1447290092297539592
#
#
# DOC 57 has been retrieved
# tweet : RT @WHOWPRO: Do you know someone who is considering suicide?
#
# Here are some ways to help ⬇
#
# 👉🏽https://t.co/0NT8USLCY1
#
#  #PreventSuicide…
# username : World Health Organization (WHO)
# date : Mon Oct 11 04:41:14 +0000 2021
# hashtags : [{'text': 'PreventSuicide', 'indices': [123, 138]}]
# likes : 0
# retweets : 42
# url : https://twitter.com/WHO/status/1447422012511641601

# %%
terms = ["hi", "i", "i", "am" ,"potato", "am", "am"]
query_terms_count = collections.Counter(terms)

query_norm = la.norm(list(query_terms_count.values()))

for termIndex, term in enumerate(terms):  #termIndex is the index of the term in the query
    if term not in index:
        continue
  
 ## Compute tf*idf(normalize TF as done with documents)
    #query_vector[termIndex] =  query_terms_count[term]
    
print(query_terms_count["am"])
# Out:
# 3
